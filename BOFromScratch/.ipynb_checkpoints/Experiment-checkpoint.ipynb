# %%
import os 
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from GP.gpr import GaussianProcessRegression
from GP.plotting import plot

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sigma_noise = 0.2

X = np.random.uniform(0, 10, size=(10))
y = np.sin(X) + np.random.normal(0, sigma_noise ** 2, X.shape[0])
X = X[:, np.newaxis]

gr = GaussianProcessRegression(noisy=False)
gr.fit(X, y)
plot(gr, [(0, 10)], ax=plt)

# %%
sigma_noise = 0.05
X = np.random.uniform(-3.,3.,(50,2))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2])+np.random.randn(50,1)*sigma_noise
Y = Y.flatten()
gr = GaussianProcessRegression(noisy=False)
gr.fit(X, y)
plot(gr, [(0, 10)], ax=plt)
# Out:
# (50,)
# ****
# (50, 50)
# (10,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-187-66671b1bc6b8> in <module>
#       5 print(Y.shape)
#       6 gr = GaussianProcessRegression(noisy=False)
# ----> 7 gr.fit(X, y)
#       8 plot(gr, [(0, 10)], ax=plt)
#
# ~/Desktop/programming/BO/GP/gpr.py in fit(self, X, y)
#      34         self.X_train = X.copy()
#      35         self.y_train = y.copy()
# ---> 36         self.optimize()
#      37
#      38     def predict(self, X, return_cov=False):
#
# ~/Desktop/programming/BO/GP/gpr.py in optimize(self, num_run)
#      86             start_point = np.array([np.random.uniform(bounds_to_sample_from[key][0], bounds_to_sample_from[key][1])
#      87                                     for key in param_names])
# ---> 88             res = minimize(lambda x: self.log_likelihood(to_dict(x)),
#      89                            start_point,
#      90                            bounds=to_array(self.kernel.get_bounds()),
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     607                                   **options)
#     608     elif meth == 'l-bfgs-b':
# --> 609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     288     if jac is None:
#     289         def func_and_grad(x):
# --> 290             f = fun(x, *args)
#     291             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     292             return f, g
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/Desktop/programming/BO/GP/gpr.py in <lambda>(x)
#      86             start_point = np.array([np.random.uniform(bounds_to_sample_from[key][0], bounds_to_sample_from[key][1])
#      87                                     for key in param_names])
# ---> 88             res = minimize(lambda x: self.log_likelihood(to_dict(x)),
#      89                            start_point,
#      90                            bounds=to_array(self.kernel.get_bounds()),
#
# ~/Desktop/programming/BO/GP/gpr.py in log_likelihood(self, theta)
#      55         print(self.K_cholesky.shape)
#      56         print(self.y_train.shape)
# ---> 57         S1 = solve_triangular(self.K_cholesky, self.y_train, lower=True)
#      58         S2 = solve_triangular(self.K_cholesky.T, S1, lower=False)
#      59
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/linalg/basic.py in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, debug, check_finite)
#     338         raise ValueError('expected square matrix')
#     339     if a1.shape[0] != b1.shape[0]:
# --> 340         raise ValueError('incompatible dimensions')
#     341     overwrite_b = overwrite_b or _datacopied(b1, b)
#     342     if debug:
#
# ValueError: incompatible dimensions
