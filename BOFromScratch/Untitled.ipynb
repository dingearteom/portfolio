# %%
import GPyOpt

# %%
from BO.bo import BO
import numpy as np
from GP.plotting import plot
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def f(x):
    return np.sin(x)

# %%
my_model = BO(f, [(0, 2 * np.pi)])

# %%
my_model.run_optimization(0)

# %%
plot(my_model.gr, [(0, 2 * np.pi)])
