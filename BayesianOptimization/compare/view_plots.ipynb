# %%
import sys
import os
os.chdir('../')
del sys.path[0]
sys.path.insert(0, os.getcwd())

# %%
with open('compare/data/pictures_log/artificial/main/trajectories/1_Bot_4_Sim/BayesianOptimization.pickle', 'rb') as fp:
    ax = pickle.load(fp)

# %%
plt.subplots?
