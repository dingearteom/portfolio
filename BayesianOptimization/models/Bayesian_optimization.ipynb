# %%
import sys
import os

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline  
import GPy
import GPyOpt
from numpy.random import seed
import numpy as np
import matplotlib
import deminf_data
import matplotlib.pyplot as plt
plt.style.use('classic')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
objective1 = deminf_data.Objective.from_name('3_DivMig_8_Sim', negate=True, type_of_transform='logarithm')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-74ddf1d073ef> in <module>
# ----> 1 objective1 = deminf_data.Objective.from_name('3_DivMig_8_Sim', negate=True, type_of_transform='logarithm')
#
# ~/anaconda3/lib/python3.8/site-packages/deminf_data-0.0.0-py3.8.egg/deminf_data/objective.py in from_name(name, negate, type_of_transform)
#      87         :type type_of_transform: str
#      88         """
# ---> 89         obj_data = DemInfData.from_name(name)
#      90         obj_function = wrap_dem_inf_function(obj_data.model_func,
#      91                                              obj_data.afs_data)
#
# ~/anaconda3/lib/python3.8/site-packages/deminf_data-0.0.0-py3.8.egg/deminf_data/load_data.py in from_name(name)
#     122         model_info = load_module(name, "main_script.py", base_dir)
#     123
# --> 124         obj = DemInfData(name=name,
#     125                          afs_data=afs_data,
#     126                          sequence_length=model_info.L,
#
# ~/anaconda3/lib/python3.8/site-packages/deminf_data-0.0.0-py3.8.egg/deminf_data/load_data.py in __init__(self, name, afs_data, sequence_length, model_func, mutation_rate, pop_labels, par_labels, lower_bound, upper_bound, popt, max_ll)
#     100         # checks
#     101         assert self.number_of_populations == int(self.name.split("_")[0])
# --> 102         assert self.number_of_parameters == len(self.lower_bound)
#     103         assert self.number_of_parameters == len(self.upper_bound)
#     104         assert self.number_of_parameters == len(self.popt)
#
# AssertionError:

# %%
bounds = []
ind = 1
for l, r in zip(objective1.lower_bound, objective1.upper_bound):
    bounds.append({'name':f'var_{ind}', 'type':'continuous', 'domain':(l, r)})
    ind += 1

# %%
bounds
# Out:
# [{'name': 'var_1',
#   'type': 'continuous',
#   'domain': (-6.907755278982137, 4.605170185988092)},
#  {'name': 'var_2',
#   'type': 'continuous',
#   'domain': (-6.907755278982137, 4.605170185988092)},
#  {'name': 'var_3',
#   'type': 'continuous',
#   'domain': (-34.538776394910684, 1.6094379124341003)},
#  {'name': 'var_4',
#   'type': 'continuous',
#   'domain': (-34.538776394910684, 1.6094379124341003)}]

# %% [markdown]
# # Bayesian optimization

# %%
def f(x):
    return [objective1(x[i]) for i in range(len(x))]

# %%
myBopt = GPyOpt.methods.BayesianOptimization(f=f,
                                             domain=bounds,
                                             model_type='GP',
                                             acquisition_type='EI',
                                             normalize_Y=True,
                                             acquisition_weight=2,
                                             num_cores=1)

# %%
# Run the optimization
max_iter = 10     # evaluation budget 
eps      = 10e-6  # Minimum allows distance between the las two observations

myBopt.run_optimization(max_iter)

# %%
myBopt.plot_acquisition(fixed_values=[None,  -1, None, -19.26009325])

# %%
myBopt.plot_acquisition(fixed_values=[-2.06278553, -1, None, -1], outsider_percents=(0.05, 0.05))

# %%
plot?

# %%
myBopt.plot_convergence()

# %%
myBopt.fx_opt
# Out:
# 446.1132956504489

# %%
myBopt.x_opt
# Out:
# array([ -1.50958663,  -5.51658126,  -2.00042405, -19.26009325])
