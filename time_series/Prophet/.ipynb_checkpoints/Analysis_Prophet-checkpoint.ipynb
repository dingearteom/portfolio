# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc
import warnings

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def MAPE(y_true, y_pred):
    assert len(y_true) == len(y_pred)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    n = len(y_true)
    return np.sum(np.abs((y_true - y_pred) / y_pred)) / n

# %%
from model import MyProphet
from transform import Transform
from evaluation import GridSearchCV

# %%
df = pd.read_csv('../data/train.csv')

# %%
def analysis(df, cv, transform, inv_transform, params_transform, TEST_SIZE=70, plot=False, **kwargs):
    # kwargs:
    # changepoint_prior_scale
    # changepoint_range
    
    df = df.copy()
    df = df[:df.shape[0] - TEST_SIZE * (cv - 1)]
    TRAIN_SIZE = df.shape[0] - TEST_SIZE
    df_train = df[:TRAIN_SIZE]
    df_test = df[TRAIN_SIZE:]
    df_train.y = transform(df_train.y)
    
    model = MyProphet(**kwargs).fit(df_train)
    df_pred = model.predict(model.make_future_dataframe(periods=TEST_SIZE, freq='H'))
    df_pred.y = inv_transform(df_pred.y, **params_transform)
    df_train.y = inv_transform(df_train.y, **params_transform)
    
    if (plot):
        fig = plt.figure()
        ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])
        ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])
        ax1.plot(df_train.index, df_train.y)
        ax1.plot(df_pred.index[TRAIN_SIZE:], df_pred.y[TRAIN_SIZE:])
        ax1.legend(['train', 'predict'])

        ax2.plot(df_train.index, df_train.y)
        ax2.plot(df_test.index, df_test.y)
        ax2.legend(['train', 'test'])
        
    
    return MAPE(df_test.y, df_pred.y[TRAIN_SIZE:])

# %%
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    results = []
    kwargs = {'changepoint_prior_scale': 1, 'changepoint_range':0.9}
    for cv in range(1, 5):
        params_transform = Transform.params_transform('boxcox_diff', df, cv)
        transform, inv_transform = Transform.
        res = analysis(df, cv, Transform.transform_boxcox_diff_ignore, Transform.inv_transform_boxcox_diff,
                       params_transform, **kwargs)
        results.append(res)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
np.mean(results)
# Out:
# 0.13405430072729074

# %%
results
# Out:
# [0.2031154532162388,
#  0.12495557572010037,
#  0.13775979248769782,
#  0.07038638148512603]

# %%
kwargs = {'changepoint_prior_scale': 1, 'changepoint_range':0.9}
params_transform = Transform.params_transform('boxcox_diff', df, cv=1)
res = analysis(df, 1, Transform.transform_boxcox_diff_ignore, Transform.inv_transform_boxcox_diff,
               params_transform, plot=True, **kwargs)
# Out:
# /home/artem/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/artem/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/artem/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
params = {'name':['id', 'log'], 'changepoint_prior_scale':np.linspace(0.01, 1, 10), 'changepoint_range':np.linspace(0.8, 0.9, 4)}

# %%
gridsearch = GridSearchCV(params)
gridsearch.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# {'changepoint_prior_scale': 0.0, 'changepoint_range': 0.8}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/fbprophet/models.py in fit(self, stan_init, stan_data, **kwargs)
#     244         try:
# --> 245             self.stan_fit = self.model.optimizing(**args)
#     246         except RuntimeError:
#
# ~/anaconda3/lib/python3.8/site-packages/pystan/model.py in optimizing(self, data, seed, init, sample_file, algorithm, verbose, as_vector, **kwargs)
#     580
# --> 581         ret, sample = fit._call_sampler(stan_args)
#     582         pars = pystan.misc._par_vector2dict(sample['par'], m_pars, p_dims)
#
# ...

# %%
gridsearch.cv_results_
# Out:
#   name changepoint_prior_scale changepoint_range  \
# 0   id                    0.15               0.8
# 1   id                    0.15               0.9
# 2   id                     0.4               0.8
# 3   id                     0.4               0.9
#
#                                               params     fold1     fold2  \
# 0  {'changepoint_prior_scale': 0.15, 'changepoint...  0.152285  0.107026
# 1  {'changepoint_prior_scale': 0.15, 'changepoint...  0.160635  0.108484
# 2  {'changepoint_prior_scale': 0.4, 'changepoint_...  0.151685  0.104492
# 3  {'changepoint_prior_scale': 0.4, 'changepoint_...  0.158179  0.103671
#
#        fold3      fold4      mean
# 0  0.0944736   0.073395  0.106795
# 1   0.094892   0.062183  0.106548
# 2   0.114134  0.0832037  0.113379
# 3   0.106691  0.0602945  0.107209

# %% [markdown]
# ### Prediction

# %%
df_train = df.copy()
df_train.y = transform(df_train.y)

# %%
TRAIN_SIZE = df_train.shape[0]
TEST_SIZE = 70

model = MyProphet().fit(df_train)
df_pred = model.predict(model.make_future_dataframe(periods=TEST_SIZE, freq='H'))

df_train.y = inv_transform(df_train.y)
df_pred.y = inv_transform(df_pred.y)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
plt.figure()
plt.plot(df_train.index, df_train.y)
plt.plot(df_pred.index[TRAIN_SIZE:], df_pred.y[TRAIN_SIZE:])
plt.legend(['train', 'predict'])
plt.show()

# %%
model.plot_components()

# %%
gc.collect()
# Out:
# 20
