# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model import MyProphet
from metrics import MAPE
from transform import inv_transform

# %%
df = pd.read_csv('data/train.csv')

# %%
TEST_SIZE = 70

# %%
def analysis(df_train, cv):
    df_train = df_train.copy()
    model = MyProphet().fit(df_train)
    df_pred = model.predict(model.make_future_dataframe(periods=TEST_SIZE, freq='H'))

# %%
def analysis(cv):
    df_train = df
    model = MyProphet().fit(df_train)
    df_pred = model.predict(model.make_future_dataframe(periods=TEST_SIZE, freq='H'))

# %%
model = MyProphet().fit(df_train)
df_pred = model.predict(model.make_future_dataframe(periods=TEST_SIZE, freq='H'))
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
df_pred.y = inv_transform(df_pred.y)
df_train.y = inv_transform(df_train.y)
# Out:
# /home/artem/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
plt.figure()
plt.plot(df_train.index, df_train.y)
plt.plot(df_pred.index[TRAIN_SIZE:], df_pred.y[TRAIN_SIZE:])
#plt.plot(df_test.index, df_test.y)
plt.legend(['train', 'predict', 'ground_truth'])
plt.show()

# %%
MAPE(df_test.y, df_pred.y[TRAIN_SIZE:])
# Out:
# 0.07211646346876413

# %% [markdown]
# ### Prediction

# %%
from predict import df, df_pred, TRAIN_SIZE, TEST_SIZE

# %%
plt.figure()
plt.plot(df.index, df.y)
plt.plot(df_pred.index[TRAIN_SIZE:], df_pred.y[TRAIN_SIZE:])
plt.legend(['train', 'predict'])
plt.show()

# %%
gc.collect()
# Out:
# 20
